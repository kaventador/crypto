# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import statsmodels.api as sm

# %%
df = yf.download(tickers='ETH-USD' , start='2023-01-10')
df
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                    Open         High  ...    Adj Close       Volume
# Date                                  ...
# 2023-01-10  1321.395508  1342.757202  ...  1336.586060   5830173253
# 2023-01-11  1336.486816  1387.932739  ...  1387.932739   6314904311
# 2023-01-12  1405.351440  1432.281250  ...  1417.938477  12230193038
# 2023-01-13  1417.946167  1461.672729  ...  1451.614868   7684148212
# 2023-01-14  1451.428467  1563.739136  ...  1550.706909  15444626014
# ...                 ...          ...  ...          ...          ...
# 2024-01-06  2269.540039  2271.359375  ...  2241.624756   5970741680
# 2024-01-07  2242.012695  2257.127930  ...  2222.865967   6490053615
# 2024-01-08  2222.857666  2358.815674  ...  2333.032715  13830287095
# 2024-01-09  2332.868164  2369.641602  ...  2344.827148  14891130716
# 2024-01-10  2344.923584  2425.304932  ...  2409.933350  18924756992
#
# [366 rows x 6 columns]

# %%
def slope(df,n):
    data = df['Close']
    slopes = [i*0 for i in range(n-1)]
    for i in range(n,len(data)+1):
        y = data[i-n:i]
        x = np.array(range(n))
        y_scaled = (y - y.min())/(y.max()-y.min())
        x_scaled = (x - x.min())/(x.max()-x.min())
        x_scaled = sm.add_constant(x_scaled)
        model = sm.OLS(y_scaled,x_scaled)
        results = model.fit()
        slopes.append(results.params[-1])
    slope_angle = (np.rad2deg(np.arctan(np.array(slopes))))
    return np.array(slope_angle)

# %%
df['slope'] = slope(df,5)
df
# Out:
#                    Open         High  ...       Volume      slope
# Date                                  ...
# 2023-01-10  1321.395508  1342.757202  ...   5830173253   0.000000
# 2023-01-11  1336.486816  1387.932739  ...   6314904311   0.000000
# 2023-01-12  1405.351440  1432.281250  ...  12230193038   0.000000
# 2023-01-13  1417.946167  1461.672729  ...   7684148212   0.000000
# 2023-01-14  1451.428467  1563.739136  ...  15444626014  42.581917
# ...                 ...          ...  ...          ...        ...
# 2024-01-06  2269.540039  2271.359375  ...   5970741680 -25.183305
# 2024-01-07  2242.012695  2257.127930  ...   6490053615  -1.260357
# 2024-01-08  2222.857666  2358.815674  ...  13830287095  16.619614
# 2024-01-09  2332.868164  2369.641602  ...  14891130716  38.642096
# 2024-01-10  2344.923584  2425.304932  ...  18924756992  44.437723
#
# [366 rows x 7 columns]

# %%
df.iloc[:,[4,6]].plot(subplots=True , layout = (2,1) , figsize=(16,8))
# Out:
# array([[<Axes: xlabel='Date'>],
#        [<Axes: xlabel='Date'>]], dtype=object)
