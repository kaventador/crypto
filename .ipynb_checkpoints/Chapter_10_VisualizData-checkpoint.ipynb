# %%
import pandas as pd
import pandas_datareader as wb
import matplotlib.pyplot as plt
import datetime
import yfinance as yf

# %%
start_date = datetime.datetime(2019, 1, 1)
end_date = datetime.datetime(2020, 1, 1)

data = yf.download(['BTC-USD'], start=start_date, end=end_date)

df = pd.DataFrame(data)

print(df.head())
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2019-01-01  3746.713379  3850.913818  3707.231201  3843.520020  3843.520020
# 2019-01-02  3849.216309  3947.981201  3817.409424  3943.409424  3943.409424
# 2019-01-03  3931.048584  3935.685059  3826.222900  3836.741211  3836.741211
# 2019-01-04  3832.040039  3865.934570  3783.853760  3857.717529  3857.717529
# 2019-01-05  3851.973877  3904.903076  3836.900146  3845.194580  3845.194580
#
#                 Volume
# Date
# 2019-01-01  4324200990
# 2019-01-02  5244856836
# 2019-01-03  4530215219
# 2019-01-04  4847965467
# 2019-01-05  5137609824

# %%
plt.figure(figsize=(16,8))
plt.plot(df['Close'] , label='Close Price')
plt.title('Historical Price')
plt.xlabel('Date')
plt.ylabel('Price (USD)')
plt.legend()
plt.show()

# %%
tickers = ['BTC-USD' , 'ETH-USD' , 'ADA-USD' , 'TRX-USD']
data = pd.DataFrame()
for a in tickers:
    data[a]= yf.download(a , start='2019-01-01' , end='2020-01-01')['Close']
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 365 entries, 2019-01-01 to 2019-12-31
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   BTC-USD  365 non-null    float64
#  1   ETH-USD  365 non-null    float64
#  2   ADA-USD  365 non-null    float64
#  3   TRX-USD  365 non-null    float64
# dtypes: float64(4)
# memory usage: 14.3 KB

# %%
data
# Out:
#                 BTC-USD     ETH-USD   ADA-USD   TRX-USD
# Date
# 2019-01-01  3843.520020  140.819412  0.042547  0.019561
# 2019-01-02  3943.409424  155.047684  0.045258  0.020222
# 2019-01-03  3836.741211  149.135010  0.042682  0.020088
# 2019-01-04  3857.717529  154.581940  0.043812  0.021492
# 2019-01-05  3845.194580  155.638596  0.044701  0.022294
# ...                 ...         ...       ...       ...
# 2019-12-27  7290.088379  127.214607  0.033100  0.013300
# 2019-12-28  7317.990234  128.322708  0.033632  0.013515
# 2019-12-29  7422.652832  134.757980  0.034284  0.013743
# 2019-12-30  7292.995117  132.633484  0.033594  0.013400
# 2019-12-31  7193.599121  129.610855  0.032845  0.013306
#
# [365 rows x 4 columns]

# %%
data.iloc[0]
# Out:
# BTC-USD    3843.520020
# ETH-USD     140.819412
# ADA-USD       0.042547
# TRX-USD       0.019561
# Name: 2019-01-01 00:00:00, dtype: float64

# %%
plt.figure(figsize=(16,8))
plt.plot(data/data.iloc[0]*100)
plt.show()

# %%
plt.figure(figsize=(16,8))
for i in tickers:
    data[i].plot(legend=True)
    
plt.xlabel('Date')
plt.ylabel('Price (USD)')
plt.show()
