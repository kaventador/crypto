# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = yf.download(tickers='XRP-USD',start='2023-01-10')
df
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                 Open      High       Low     Close  Adj Close      Volume
# Date
# 2023-01-10  0.349325  0.353811  0.345308  0.351241   0.351241   815342810
# 2023-01-11  0.351254  0.376026  0.348716  0.374158   0.374158  1498360174
# 2023-01-12  0.373827  0.378322  0.365869  0.375197   0.375197  1226464922
# 2023-01-13  0.375186  0.386446  0.370640  0.385804   0.385804   990539135
# 2023-01-14  0.385807  0.407890  0.385807  0.395443   0.395443  1601102466
# ...              ...       ...       ...       ...        ...         ...
# 2024-01-06  0.576512  0.576512  0.559386  0.568512   0.568512   820534691
# 2024-01-07  0.568521  0.572776  0.548477  0.551741   0.551741   901525412
# 2024-01-08  0.551716  0.581595  0.550675  0.577923   0.577923  2011066819
# 2024-01-09  0.577964  0.578510  0.557197  0.566633   0.566633  1740178857
# 2024-01-10  0.566672  0.572249  0.563447  0.565898   0.565898  1717280896
#
# [366 rows x 6 columns]

# %%
def OBV(DF):
    df = DF.copy()
    df['daily ret'] = df['Close'].pct_change()
    df['direction'] = np.where(df['daily ret']>0 , 1 ,-1)
    df['direction'][0] = 0
    df['adj volume'] = df['Volume']*df['direction']
    df['obv'] = df['adj volume'].cumsum()
    return df['obv']

# %%
data = OBV(df)
data
# Out:
# C:\Users\moham\AppData\Local\Temp\ipykernel_12228\3262277299.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['direction'][0] = 0
# Date
# 2023-01-10              0
# 2023-01-11     1498360174
# 2023-01-12     2724825096
# 2023-01-13     3715364231
# 2023-01-14     5316466697
#                  ...
# 2024-01-06    17867229669
# 2024-01-07    16965704257
# 2024-01-08    18976771076
# 2024-01-09    17236592219
# 2024-01-10    15519311323
# Name: obv, Length: 366, dtype: int64

# %%
plt.figure(figsize=(16,8))
ax1 = plt.subplot2grid((11,1),(0,0),rowspan= 5 , colspan= 1)
ax2 = plt.subplot2grid((11,1),(6,0),rowspan= 5 , colspan= 1)

ax1.plot(df['Close'],linewidth = 2 , label ="PRICE" , color='#ff9800')
ax1.set_title('Closing Price')
ax2.plot(data,linewidth = 3 , label ="OBV" , color='#26a69a',alpha=0.3)
ax2.set_title('OBV INDICATOR')



ax1.legend()
ax2.legend()
plt.show()
