# %%
from yahoo_fin.stock_info import get_data
import pandas as pd

# %%
BTC_weekly = get_data('BTC-USD',start_date='2023-01-01',index_as_date=True,interval='1wk')
BTC_weekly
# Out:
#                     open          high  ...        volume   ticker
# 2023-01-01  16547.914062  16991.994141  ...   89488148109  BTC-USD
# 2023-01-08  16954.146484  21075.142578  ...  165738340554  BTC-USD
# 2023-01-15  20977.484375  23282.347656  ...  183490791382  BTC-USD
# 2023-01-22  22777.986328  23722.099609  ...  174809626508  BTC-USD
# 2023-01-29  23031.449219  24167.210938  ...  178939668423  BTC-USD
# 2023-02-05  23332.248047  23423.435547  ...  171955806387  BTC-USD
# 2023-02-12  21870.902344  25134.117188  ...  201316241512  BTC-USD
# 2023-02-19  24640.027344  25126.851562  ...  189383308297  BTC-USD
# 2023-02-26  23174.150391  23880.632812  ...  142118319009  BTC-USD
# 2023-03-05  22354.144531  22613.685547  ...  176095432558  BTC-USD
# 2023-03-12  20628.029297  27787.812500  ...  297342689722  BTC-USD
# 2023-03-19  26969.503906  28803.335938  ...  215611441879  BTC-USD
# 2023-03-26  27495.523438  29159.902344  ...  122848952111  BTC-USD
# ...

# %%
import yahoo_fin.stock_info as si

quote_table = si.get_quote_table("ETH-USD", dict_result=False)
quote_table
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10776\2201143279.py in ?()
#       1 import yahoo_fin.stock_info as si
#       2
# ----> 3 quote_table = si.get_quote_table("ETH-USD", dict_result=False)
#       4 quote_table
#
# O:\anaconda\Lib\site-packages\yahoo_fin\stock_info.py in ?(ticker, dict_result, headers)
#     291     site = "https://finance.yahoo.com/quote/" + ticker + "?p=" + ticker
#     292
#     293     tables = pd.read_html(requests.get(site, headers=headers).text)
#     294
# --> 295     data = tables[0].append(tables[1])
#     296
#     297     data.columns = ["attribute" , "value"]
#     298
#
# O:\anaconda\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
# ...

# %%
si.get_quote_table("ETH-USD")["Market Cap"]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10776\3806874392.py in ?()
# ----> 1 si.get_quote_table("ETH-USD")["Market Cap"]
#
# O:\anaconda\Lib\site-packages\yahoo_fin\stock_info.py in ?(ticker, dict_result, headers)
#     291     site = "https://finance.yahoo.com/quote/" + ticker + "?p=" + ticker
#     292
#     293     tables = pd.read_html(requests.get(site, headers=headers).text)
#     294
# --> 295     data = tables[0].append(tables[1])
#     296
#     297     data.columns = ["attribute" , "value"]
#     298
#
# O:\anaconda\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
# ...

# %%
si.get_quote_table("ADA-USD")["Avg. Volume"]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10776\3244446337.py in ?()
# ----> 1 si.get_quote_table("ADA-USD")["Avg. Volume"]
#
# O:\anaconda\Lib\site-packages\yahoo_fin\stock_info.py in ?(ticker, dict_result, headers)
#     291     site = "https://finance.yahoo.com/quote/" + ticker + "?p=" + ticker
#     292
#     293     tables = pd.read_html(requests.get(site, headers=headers).text)
#     294
# --> 295     data = tables[0].append(tables[1])
#     296
#     297     data.columns = ["attribute" , "value"]
#     298
#
# O:\anaconda\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# ...

# %%
si.get_quote_table("TRX-USD")["Day's Range"]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10776\720289836.py in ?()
# ----> 1 si.get_quote_table("TRX-USD")["Day's Range"]
#
# O:\anaconda\Lib\site-packages\yahoo_fin\stock_info.py in ?(ticker, dict_result, headers)
#     291     site = "https://finance.yahoo.com/quote/" + ticker + "?p=" + ticker
#     292
#     293     tables = pd.read_html(requests.get(site, headers=headers).text)
#     294
# --> 295     data = tables[0].append(tables[1])
#     296
#     297     data.columns = ["attribute" , "value"]
#     298
#
# O:\anaconda\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
# ...

# %%
daily_range = si.get_quote_table("TRX-USD")["Day's Range"]
daily_low = float(daily_range.split(" - ")[0])
daily_high = float(daily_range.split(" - ")[1])
print("daily low:", daily_low)
print("daily high:", daily_high)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10776\1264297004.py in ?()
# ----> 1 daily_range = si.get_quote_table("TRX-USD")["Day's Range"]
#       2 daily_low = float(daily_range.split(" - ")[0])
#       3 daily_high = float(daily_range.split(" - ")[1])
#       4 print("daily low:", daily_low)
#
# O:\anaconda\Lib\site-packages\yahoo_fin\stock_info.py in ?(ticker, dict_result, headers)
#     291     site = "https://finance.yahoo.com/quote/" + ticker + "?p=" + ticker
#     292
#     293     tables = pd.read_html(requests.get(site, headers=headers).text)
#     294
# --> 295     data = tables[0].append(tables[1])
#     296
#     297     data.columns = ["attribute" , "value"]
#     298
#
# O:\anaconda\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
# ...

# %%
income_statement = si.get_income_statement("aapl")
income_statement
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 income_statement = si.get_income_statement("aapl")
#       2 income_statement
#
# File O:\anaconda\Lib\site-packages\yahoo_fin\stock_info.py:422, in get_income_statement(ticker, yearly)
#     419 json_info = _parse_json(income_site)
#     421 if yearly:
# --> 422     temp = json_info["incomeStatementHistory"]["incomeStatementHistory"]
#     423 else:
#     424     temp = json_info["incomeStatementHistoryQuarterly"]["incomeStatementHistory"]
#
# TypeError: string indices must be integers, not 'str'

# %%
balance_sheet = si.get_balance_sheet("aapl")
balance_sheet
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
import yahoo_fin.options as ops

# %%
expiration_dates = ops.get_expiration_dates("aapl")
expiration_dates
# Out:
# ['January 12, 2024',
#  'January 19, 2024',
#  'January 26, 2024',
#  'February 2, 2024',
#  'February 9, 2024',
#  'February 16, 2024',
#  'February 23, 2024',
#  'March 15, 2024',
#  'April 19, 2024',
#  'May 17, 2024',
#  'June 21, 2024',
#  'July 19, 2024',
#  'August 16, 2024',
#  'September 20, 2024',
#  'December 20, 2024',
#  'January 17, 2025',
#  'June 20, 2025',
#  'September 19, 2025',
#  'December 19, 2025',
#  'January 16, 2026',
#  'June 18, 2026']

# %%
ops.get_calls("aapl")
# Out:
#           Contract Name  ... Implied Volatility
# 0   AAPL240112C00060000  ...              0.00%
# 1   AAPL240112C00070000  ...              0.00%
# 2   AAPL240112C00075000  ...              0.00%
# 3   AAPL240112C00080000  ...              0.00%
# 4   AAPL240112C00085000  ...              0.00%
# 5   AAPL240112C00100000  ...              0.00%
# 6   AAPL240112C00125000  ...              0.00%
# 7   AAPL240112C00130000  ...              0.00%
# 8   AAPL240112C00135000  ...              0.00%
# 9   AAPL240112C00140000  ...              0.00%
# 10  AAPL240112C00145000  ...              0.00%
# 11  AAPL240112C00150000  ...              0.00%
# 12  AAPL240112C00155000  ...              0.00%
# 13  AAPL240112C00157500  ...              0.00%
# 14  AAPL240112C00160000  ...              0.00%
# 15  AAPL240112C00162500  ...              0.00%
# 16  AAPL240112C00165000  ...              0.00%
# 17  AAPL240112C00167500  ...              0.00%
# 18  AAPL240112C00170000  ...              0.00%
# ...
